# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb

# %%
#Importing Dataset
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

# %%
#Manual OneHotEncoding
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1
    return results
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
#Vectorize Labels
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
#Creating Neural Network
from tensorflow.keras import models, layers
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
#Compiling Model
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy']
             )

# %%
#Validation Set
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
#Training Model
histiry = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 20s 1ms/sample - loss: 0.5004 - accuracy: 0.7913 - val_loss: 0.3663 - val_accuracy: 0.8723
# Epoch 2/20
# 15000/15000 [==============================] - 11s 700us/sample - loss: 0.2891 - accuracy: 0.9077 - val_loss: 0.2961 - val_accuracy: 0.8867
# Epoch 3/20
# 15000/15000 [==============================] - 4s 259us/sample - loss: 0.2109 - accuracy: 0.9309 - val_loss: 0.2939 - val_accuracy: 0.8817
# Epoch 4/20
# 15000/15000 [==============================] - 5s 339us/sample - loss: 0.1646 - accuracy: 0.9472 - val_loss: 0.3303 - val_accuracy: 0.8656
# Epoch 5/20
# 15000/15000 [==============================] - 4s 283us/sample - loss: 0.1386 - accuracy: 0.9558 - val_loss: 0.2851 - val_accuracy: 0.8883
# Epoch 6/20
# 15000/15000 [==============================] - 4s 270us/sample - loss: 0.1103 - accuracy: 0.9673 - val_loss: 0.3027 - val_accuracy: 0.8850
# Epoch 7/20
# 15000/15000 [==============================] - 5s 310us/sample - loss: 0.0917 - accuracy: 0.9720 - val_loss: 0.3141 - val_accuracy: 0.8843
# Epoch 8/20
# 15000/15000 [==============================] - 4s 270us/sample - loss: 0.0737 - accuracy: 0.9799 - val_loss: 0.3366 - val_accuracy: 0.8818
# Epoch 9/20
# 15000/15000 [==============================] - 4s 258us/sample - loss: 0.0605 - accuracy: 0.9843 - val_loss: 0.3986 - val_accuracy: 0.8668
# Epoch 10/20
# 15000/15000 [==============================] - 4s 246us/sample - loss: 0.0469 - accuracy: 0.9901 - val_loss: 0.3898 - val_accuracy: 0.8762
# Epoch 11/20
# 15000/15000 [==============================] - 3s 231us/sample - loss: 0.0403 - accuracy: 0.9914 - val_loss: 0.4231 - val_accuracy: 0.8722
# Epoch 12/20
# 15000/15000 [==============================] - 4s 244us/sample - loss: 0.0338 - accuracy: 0.9923 - val_loss: 0.4475 - val_accuracy: 0.8754
# Epoch 13/20
# 15000/15000 [==============================] - 4s 238us/sample - loss: 0.0256 - accuracy: 0.9949 - val_loss: 0.4834 - val_accuracy: 0.8733
# Epoch 14/20
# 15000/15000 [==============================] - 3s 224us/sample - loss: 0.0189 - accuracy: 0.9978 - val_loss: 0.5097 - val_accuracy: 0.8724
# Epoch 15/20
# 15000/15000 [==============================] - 4s 252us/sample - loss: 0.0147 - accuracy: 0.9981 - val_loss: 0.5397 - val_accuracy: 0.8703
# Epoch 16/20
# 15000/15000 [==============================] - 5s 314us/sample - loss: 0.0126 - accuracy: 0.9986 - val_loss: 0.5741 - val_accuracy: 0.8712
# Epoch 17/20
# 15000/15000 [==============================] - 4s 291us/sample - loss: 0.0109 - accuracy: 0.9985 - val_loss: 0.6130 - val_accuracy: 0.8701
# Epoch 18/20
# 15000/15000 [==============================] - 3s 231us/sample - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.6866 - val_accuracy: 0.8564
# Epoch 19/20
# 15000/15000 [==============================] - 3s 221us/sample - loss: 0.0044 - accuracy: 0.9999 - val_loss: 0.7084 - val_accuracy: 0.8567
# Epoch 20/20
# 15000/15000 [==============================] - 3s 223us/sample - loss: 0.0080 - accuracy: 0.9981 - val_loss: 0.7274 - val_accuracy: 0.8672

# %%
model.evaluate(x_test, y_test)
# Out:
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.7820965714144706, 0.85192]
